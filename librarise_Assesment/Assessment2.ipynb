# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Ramani Rushik\Downloads\historical_automobile_sales.csv")
df
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
data2 = df[df["Automobile_Sales"] < 15000]

# %%
plt.plot(df["Year"], df["Automobile_Sales"])
plt.show()

# %%
sns.lineplot(data = df , x = "Year" , y = "Automobile_Sales")
# Out:
# <Axes: xlabel='Year', ylabel='Automobile_Sales'>

# %%
plt.figure(figsize = (10,5))
sns.lineplot(data = df , x = "Year" , y = "Automobile_Sales" , hue = "Vehicle_Type",marker="o")
# Out:
# <Axes: xlabel='Year', ylabel='Automobile_Sales'>

# %%
grouped = df.groupby(['Year', 'Vehicle_Type'])['Automobile_Sales'].sum().reset_index()

# Plot style
sns.set(style="whitegrid")
# Create the line plot
plt.figure(figsize=(10, 5))
sns.lineplot(data=grouped, x='Year', y='Automobile_Sales', hue='Vehicle_Type', marker='o')
# Out:
# <Axes: xlabel='Year', ylabel='Automobile_Sales'>

# %%
df2 = df[df["Recession"] == 1]

# %%
plt.figure(figsize = (10,4))
sns.barplot(data = df, x = "Vehicle_Type" , y = "Automobile_Sales", hue="Recession" )
# Out:
# <Axes: xlabel='Vehicle_Type', ylabel='Automobile_Sales'>
